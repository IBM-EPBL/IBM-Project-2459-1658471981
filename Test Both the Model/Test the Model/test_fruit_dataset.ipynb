# %%
test_dir=r'C:\Users\ebene\Downloads\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\fruit-dataset\fruit-dataset'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Convolution2D,MaxPooling2D,Flatten 
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 7070 images belonging to 2 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
from PIL import Image
img = Image.open(r'C:\Users\ebene\Downloads\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\fruit-dataset\fruit-dataset\test\Corn_(maize)___healthy\0a1a49a8-3a95-415a-b115-4d6d136b980b___R.S_HL 8216 copy.jpg')
img.show()

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)

# %%
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']
index[0]
# Out:
# 'Apple___Black_rot'

# %%
model=Sequential()

# %%
model.add(Dense(9,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
len(x)
# Out:
# 1

# %%
model=load_model('vegetabledata.h5')

# %%
x
# Out:
# array([[[[133., 178., 147.],
#          [135., 180., 149.],
#          [139., 184., 153.],
#          ...,
#          [109., 160., 141.],
#          [107., 158., 139.],
#          [106., 157., 138.]],
#
#         [[131., 176., 145.],
#          [132., 177., 146.],
#          [134., 179., 148.],
#          ...,
#          [103., 154., 135.],
#          [106., 157., 138.],
#          [110., 161., 142.]],
#
#         [[124., 170., 141.],
#          [125., 171., 142.],
#          [126., 172., 143.],
#          ...,
#          [ 99., 150., 131.],
#          [106., 157., 138.],
#          [114., 165., 146.]],
#
#         ...,
#
#         [[ 44.,  96.,  50.],
#          [ 44.,  96.,  50.],
#          [ 45.,  97.,  51.],
#          ...,
#          [ 74., 123.,  93.],
#          [ 85., 134., 104.],
#          [ 96., 145., 115.]],
#
#         [[ 57., 110.,  66.],
#          [ 56., 109.,  65.],
#          [ 54., 107.,  63.],
#          ...,
#          [ 76., 125.,  95.],
# ...

# %%
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']
index[2]
# Out:
# 'Corn_(maize)___healthy'

# %%
from scipy import integrate, special, stats
